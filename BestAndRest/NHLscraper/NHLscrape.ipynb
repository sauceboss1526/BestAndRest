# %% [markdown]
# NHL Best vs Rest
#
# NHL sponsorship revenue totaled northward of $1.28 billion by the end of the 2023 postseason according to SportsPro media. This is a 21% year over year gain when put into context and can be considered a material increase. More oportunities for sponsorship rise especially considering the number of fans that prospects bring with them to the NHL. Organizations looking to advertise through NHL franchises would need rookie information to predict from which amatuer team the first overall pick will come from and to which team he will be drafted by.
#
# sources :
# https://www.sportspromedia.com/news/nhl-sponsorship-revenue-2022-23-sponsorunited-marketing-report/?zephr_sso_ott=3n4fcM#:~:text=The%20National%20Hockey%20League%20(NHL,North%20American%20ice%20hockey%20property.
#
# https://thehockeynews.com/nhl/chicago-blackhawks/features/corporate-connor-from-cards-to-cars-bedard-already-has-list-of-sponsorships

# %%
# %pip install lxml
import pandas as pd
import numpy as np 
from bs4 import BeautifulSoup 
import csv 
import requests 



rdfcols = ['year', 'player', 'team', 'amateur team (league)']
rookiesdata = pd.DataFrame(columns=rdfcols)
# Out:
# Requirement already satisfied: lxml in /usr/local/python/3.10.8/lib/python3.10/site-packages (4.9.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Creating a dataset, df, in which to land the data from hockey reference website and building the web scraper.
#
#
#
# Utilizing BeautifulSoup4 (BS4)
#
#
# The website from which data is being acquired from (https://www.hockey-reference.com/draft/) is static, therefore, BeautifulSoup4 will be useful in acquiring respective data. However, the content from a website's html doc is needed for BeautifulSoup to scrape data from the website.
# "requests" is a package that requests for the html text behind the website. The html text can be passed into the BS4 scraper once the request is granted and urllib receives the data.
#
# Utilizing Pandas
#
# For this specific project, however, utilizing BS4 is not so necessary because Pandas offers a built in read_html() function.
# Pandas' read_html function looks specifically for for tables in an html doc. The table on the website is returned as a list object.
# The website of interest displays tables on its interface of NHL first round picks data.
# Hockey references posts tables of data, therefore, utilizing Pandas' pre-existing function for obtaining data from html is preferred.
#
# #here we import BeautifulScrape2

# %%
import requests
import pandas as pd 
#import regex as re
from bs4 import BeautifulSoup

#create url request
#note that self is a response object when you hover mouse over it
#websiteurl = 'https://www.hockey-reference.com/draft/'
#response = requests.get(websiteurl)

#pass the html in bs4 scraper
#note that self is an 
#soup = BeautifulSoup(response.content, "html.parser")

#find data 
#tablecols = soup.find('tr').text
#year = soup.find('td', class_="left").text
#rows = soup.find('table').text
#rows
rookiesdata1 = pd.read_html('https://www.hockey-reference.com/draft/')[0]
#re.findall([0-9]{4}, rookiesdata1.Draft[0])
#rookiesdata.year = rookiesdata1.Draft
#show data
rookiesdata1
# Out:
#                Draft                Team         First Pick  \
# 0     2023 NHL Entry  Chicago Blackhawks      Connor Bedard
# 1     2022 NHL Entry  Montreal Canadiens   Juraj Slafkovsky
# 2     2021 NHL Entry      Buffalo Sabres         Owen Power
# 3     2020 NHL Entry    New York Rangers  Alexis Lafreniere
# 4     2019 NHL Entry   New Jersey Devils        Jack Hughes
# ..               ...                 ...                ...
# 56  1967 NHL Amateur   Los Angeles Kings      Rick Pagnutti
# 57  1966 NHL Amateur       Boston Bruins        Barry Gibbs
# 58  1965 NHL Amateur    New York Rangers     Andre Veilleux
# 59  1964 NHL Amateur   Detroit Red Wings    Claude Gauthier
# 60  1963 NHL Amateur  Montreal Canadiens      Garry Monahan
#
#                              Amateur Team
# 0                       Regina Pats (WHL)
# 1                           TPS (Finland)
# 2                      Michigan (Big Ten)
# 3                Rimouski Oceanic (QMJHL)
# 4   USA U-18 Development Team (USDP/USHL)
# ..                                    ...
# 56                         Garson (NOJHL)
# 57                         Estevan (SJHL)
# 58              Montreal Rangers Jr. B ()
# 59                      Rosemount (QMJHL)
# 60                St. Michael's Majors ()
#
# [61 rows x 4 columns]

# %%
websiteurl = 'https://www.hockey-reference.com/draft/'
requests.get(websiteurl).content
# Out:
# b'\n<!DOCTYPE html>\n<html data-version="klecko-" data-root="/home/hr/build" lang="en" class="no-js" >\n<head>\n    <meta charset="utf-8">\n    <meta http-equiv="x-ua-compatible" content="ie=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=2.0" />\n    <link rel="dns-prefetch" href="https://cdn.ssref.net/req/202311031" />\n<!-- Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->\n<script type="text/javascript" async=true>\n    (function() {\n\tvar host = window.location.hostname;\n\tvar element = document.createElement(\'script\');\n\tvar firstScript = document.getElementsByTagName(\'script\')[0];\n\tvar url = \'https://cmp.quantcast.com\'\n\t    .concat(\'/choice/\', \'XwNYEpNeFfhfr\', \'/\', host, \n\t\t    \'/choice.js?tag_version=V2\');\n\tvar uspTries = 0;\n\tvar uspTriesLimit = 3;\n\telement.async = true;\n\telement.type = \'text/javascript\';\n\telement.src = url;\n\t\n\tfirstScript.parentNode.insertBefore(element, firstScript);\n\t\n\tfunction makeStub() {\n\t    var TCF_LOCATOR_NAME = \'__tcfapiLocator\';\n\t    var queue = [];\n\t    var win = window;\n\t    var cmpFrame;\n\t    \n\t    function addFrame() {\n\t\tvar doc = win.document;\n\t\tvar otherCMP = !!(win.frames[TCF_LOCATOR_NAME]);\n\t\t\n\t\tif (!otherCMP) {\n\t\t    if (doc.body) {\n\t\t\tvar iframe = doc.createElement(\'iframe\');\n\t\t\t\n\t\t\tiframe.style.cssText = \'display:none\';\n\t\t\tiframe.name = TCF_LOCATOR_NAME;\n\t\t\tdoc.body.appendChild(iframe);\n\t\t    } else {\n\t\t\tsetTimeout(addFrame, 5);\n\t\t    }\n\t\t}\n\t\treturn !otherCMP;\n\t    }\n\t    \n\t    function tcfAPIHandler() {\n\t\tvar gdprApplies;\n\t\tvar args = arguments;\n\t\t\n\t\tif (!args.length) {\n\t\t    return queue;\n\t\t} else if (args[0] === \'setGdprApplies\') {\n\t\t    if (\n\t\t\targs.length > 3 &&\n\t\t\t    args[2] === 2 &&\n\t\t\t    typeof args[3] === \'boolean\'\n\t\t    ) {\n\t\t\tgdprApplies = args[3];\n\t\t\tif (typeof args[2] === \'function\') {\n\t\t\t    args[2](\'set\', true);\n\t\t\t}\n\t\t    }\n\t\t} else if (args[0] === \'ping\') {\n\t\t    var retr = {\n\t\t\tgdprApplies: gdprApplies,\n\t\t\tcmpLoaded: false,\n\t\t\tcmpStatus: \'stub\'\n\t\t    };\n\t\t    \n\t\t    if (typeof args[2] === \'function\') {\n\t\t\targs[2](retr);\n\t\t    }\n\t\t} else {\n\t\t    if(args[0] === \'init\' && typeof args[3] === \'object\') {\n\t\t\targs[3] = Object.assign(args[3], { tag_version: \'V2\' });\n\t\t    }\n\t\t    queue.push(args);\n\t\t}\n\t    }\n\t    \n\t    function postMessageEventHandler(event) {\n\t\tvar msgIsString = typeof event.data === \'string\';\n\t\tvar json = {};\n\t\t\n\t\ttry {\n\t\t    if (msgIsString) {\n\t\t\tjson = JSON.parse(event.data);\n\t\t    } else {\n\t\t\tjson = event.data;\n\t\t    }\n\t\t} catch (ignore) {}\n\t\t\n\t\tvar payload = json.__tcfapiCall;\n\t\t\n\t\tif (payload) {\n\t\t    window.__tcfapi(\n\t\t\tpayload.command,\n\t\t\tpayload.version,\n\t\t\tfunction(retValue, success) {\n\t\t\t    var returnMsg = {\n\t\t\t\t__tcfapiReturn: {\n\t\t\t\t    returnValue: retValue,\n\t\t\t\t    success: success,\n\t\t\t\t    callId: payload.callId\n\t\t\t\t}\n\t\t\t    };\n\t\t\t    if (msgIsString) {\n\t\t\t\treturnMsg = JSON.stringify(returnMsg);\n\t\t\t    }\n\t\t\t    if (event && event.source && event.source.postMessage) {\n\t\t\t\tevent.source.postMessage(returnMsg, \'*\');\n\t\t\t    }\n\t\t\t},\n\t\t\tpayload.parameter\n\t\t    );\n\t\t}\n\t    }\n\t    \n\t    while (win) {\n\t\ttry {\n\t\t    if (win.frames[TCF_LOCATOR_NAME]) {\n\t\t\tcmpFrame = win;\n\t\t\tbreak;\n\t\t    }\n\t\t} catch (ignore) {}\n\t\t\n\t\tif (win === window.top) {\n\t\t    break;\n\t\t}\n\t\twin = win.parent;\n\t    }\n\t    if (!cmpFrame) {\n\t\taddFrame();\n\t\twin.__tcfapi = tcfAPIHandler;\n\t\twin.addEventListener(\'message\', postMessageEventHandler, false);\n\t    }\n\t};\n\t\n\tmakeStub();\n\t\n\tvar uspStubFunction = function() {\n\t    var arg = arguments;\n\t    if (typeof window.__uspapi ! ...

# %%
rookiesdata1
# Out:
#                Draft                Team         First Pick  \
# 0     2023 NHL Entry  Chicago Blackhawks      Connor Bedard
# 1     2022 NHL Entry  Montreal Canadiens   Juraj Slafkovsky
# 2     2021 NHL Entry      Buffalo Sabres         Owen Power
# 3     2020 NHL Entry    New York Rangers  Alexis Lafreniere
# 4     2019 NHL Entry   New Jersey Devils        Jack Hughes
# ..               ...                 ...                ...
# 56  1967 NHL Amateur   Los Angeles Kings      Rick Pagnutti
# 57  1966 NHL Amateur       Boston Bruins        Barry Gibbs
# 58  1965 NHL Amateur    New York Rangers     Andre Veilleux
# 59  1964 NHL Amateur   Detroit Red Wings    Claude Gauthier
# 60  1963 NHL Amateur  Montreal Canadiens      Garry Monahan
#
#                              Amateur Team
# 0                       Regina Pats (WHL)
# 1                           TPS (Finland)
# 2                      Michigan (Big Ten)
# 3                Rimouski Oceanic (QMJHL)
# 4   USA U-18 Development Team (USDP/USHL)
# ..                                    ...
# 56                         Garson (NOJHL)
# 57                         Estevan (SJHL)
# 58              Montreal Rangers Jr. B ()
# 59                      Rosemount (QMJHL)
# 60                St. Michael's Majors ()
#
# [61 rows x 4 columns]

# %%
# Out:
# Collecting lxml
#   Downloading lxml-4.9.3-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Downloading lxml-4.9.3-cp310-cp310-manylinux_2_28_x86_64.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 51.1 MB/s eta 0:00:00:00:010:01
# Installing collected packages: lxml
# Successfully installed lxml-4.9.3
# [               Draft                Team         First Pick  \
#  0     2023 NHL Entry  Chicago Blackhawks      Connor Bedard
#  1     2022 NHL Entry  Montreal Canadiens   Juraj Slafkovsky
#  2     2021 NHL Entry      Buffalo Sabres         Owen Power
#  3     2020 NHL Entry    New York Rangers  Alexis Lafreniere
#  4     2019 NHL Entry   New Jersey Devils        Jack Hughes
#  ..               ...                 ...                ...
#  56  1967 NHL Amateur   Los Angeles Kings      Rick Pagnutti
#  57  1966 NHL Amateur       Boston Bruins        Barry Gibbs
#  58  1965 NHL Amateur    New York Rangers     Andre Veilleux
#  59  1964 NHL Amateur   Detroit Red Wings    Claude Gauthier
#  60  1963 NHL Amateur  Montreal Canadiens      Garry Monahan
#
#                               Amateur Team
#  0                       Regina Pats (WHL)
#  1                           TPS (Finland)
#  2                      Michigan (Big Ten)
#  3                Rimouski Oceanic (QMJHL)
#  4   USA U-18 Development Team (USDP/USHL)
#  ..                                    ...
#  56                         Garson (NOJHL)
#  57                         Estevan (SJHL)
#  58              Montreal Rangers Jr. B ()
#  59                      Rosemount (QMJHL)
#  60                St. Michael's Majors ()
#
#  [61 rows x 4 columns],
#                  Franchise  From    To
#  0           Anaheim Ducks  1993  2023
#  1         Arizona Coyotes  1979  2023
#  2           Boston Bruins  1963  2023
#  3          Buffalo Sabres  1970  2023
#  4          Calgary Flames  1972  2023
#  5     Carolina Hurricanes  1979  2023
#  6      Chicago Blackhawks  1963  2023
#  7        Cleveland Barons  1967  1977
#  8      Colorado Avalanche  1979  2023
#  9   Columbus Blue Jackets  2000  2023
#  10           Dallas Stars  1967  2023
#  11      Detroit Red Wings  1963  2023
#  12        Edmonton Oilers  1979  2023
#  13       Florida Panthers  1993  2023
#  14      Los Angeles Kings  1967  2023
#  15         Minnesota Wild  2000  2023
#  16     Montreal Canadiens  1963  2023
#  17    Nashville Predators  1998  2023
#  18      New Jersey Devils  1974  2023
#  19     New York Islanders  1972  2023
#  20       New York Rangers  1963  2023
#  21        Ottawa Senators  1992  2023
#  22    Philadelphia Flyers  1967  2023
#  23    Pittsburgh Penguins  1967  2023
#  24        San Jose Sharks  1991  2023
#  25         Seattle Kraken  2021  2023
#  26        St. Louis Blues  1968  2023
#  27    Tampa Bay Lightning  1992  2023
#  28    Toronto Maple Leafs  1963  2023
#  29      Vancouver Canucks  1970  2023
#  30   Vegas Golden Knights  2017  2023
#  31    Washington Capitals  1974  2023
#  32          Winnipeg Jets  1999  2023]

# %%
#connecting to city of new york traffic violations data 
# %pip install sodapy

from sodapy import Socrata

# Unauthenticated client only works with public data sets. 
# Note 'None'in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", None)

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("7mxj-7a6y", limit=2000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
# Out:
# Requirement already satisfied: sodapy in /usr/local/python/3.10.8/lib/python3.10/site-packages (2.2.0)
# Requirement already satisfied: requests>=2.28.1 in /home/codespace/.local/lib/python3.10/site-packages (from sodapy) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.28.1->sodapy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.28.1->sodapy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.28.1->sodapy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.28.1->sodapy) (2023.7.22)
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# Note: you may need to restart the kernel to use updated packages.

# %%
results_df
# Out:
#      summons_number    plate_id registration_state plate_type  \
# 0        1457617912     JEB5683                 NY        PAS
# 1        1457617924     JAN2986                 NY        PAS
# 2        1457622427     FJH6630                 TX        PAS
# 3        1457638629      RD1Y5N                 MO        PAS
# 4        1457639580    T503814C                 NY        OMT
# ...             ...         ...                ...        ...
# 1995     1449933749     EFL8200                 NY        PAS
# 1996     1449933750     DAU7734                 NY        PAS
# 1997     1449933774  BLANKPLATE                 99        999
# 1998     1449933786     FDV1600                 NY        PAS
# 1999     1449933798     EKW5259                 NY        PAS
#
#                    issue_date violation_code vehicle_body_type vehicle_make  \
# 0     2021-06-25T00:00:00.000             40               VAN         FORD
# 1     2021-06-25T00:00:00.000             20              SUBN        DODGE
# 2     2021-06-17T00:00:00.000             98               SDN         AUDI
# 3     2021-06-16T00:00:00.000             98               SDN        TOYOT
# 4     2021-07-04T00:00:00.000             40              TAXI        HONDA
# ...                       ...            ...               ...          ...
# 1995  2021-06-24T00:00:00.000             21               SDN        HONDA
# 1996  2021-06-24T00:00:00.000             21               SDN        NISSA
# 1997  2021-06-24T00:00:00.000             21              SUBN        CADIL
# 1998  2021-06-24T00:00:00.000             21              SUBN        DODGE
# 1999  2021-06-24T00:00:00.000             21               SDN        TOYOT
#
#      issuing_agency street_code1  ... sub_division days_parking_in_effect  \
# 0                 P        63430  ...           C4                BBBBBBB
# 1                 P        13490  ...           E2                BBBBBBB
# 2                 P        79430  ...           E2                BBBBBBB
# 3                 P        53130  ...           C4                BBBBBBB
# 4                 P        81030  ...           F2                BBBBBBB
# ...             ...          ...  ...          ...                    ...
# 1995              P        36730  ...           D1                YBBYBBB
# 1996              P        36730  ...           D1                YBBYBBB
# 1997              P        36730  ...           D1                BBBYBBB
# 1998              P        36730  ...           D1                BBBYBBB
# 1999              P        36730  ...           D1                BBBYBBB
#
#      from_hours_in_effect to_hours_in_effect vehicle_color  \
# 0                     ALL                ALL            GY
# 1                     ALL                ALL           BLU
# 2                     ALL                ALL         WHITE
# 3                     ALL                ALL           TAN
# 4                     ALL                ALL           WHI
# ...                   ...                ...           ...
# 1995                0830A              1000A            GY
# 1996                0830A              1000A          BLUE
# 1997                0830A              1000A           BLK
# 1998                0830A              1000A          BLUE
# 1999                0830A              1000A           BLK
#
#      unregistered_vehicle vehicle_year meter_number feet_from_curb  \
# 0                       0         2007            -              3
# 1                       0         2007            -              0
# 2                       0            0            -              0
# 3                       0         2001            -              0
# 4                       0         2020            -              0
# ...                   ...          ...          ...            ...
# 1995                    0         2008            -              0
# 1996                    0         2009            -              0
# 1997                    0            0            -              0
# 1998                    0         2003            -              0
# 1999                    0            0            -              0
#
#      intersecting_street
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 1995                 NaN
# 1996                 NaN
# 1997                 NaN
# 1998                 NaN
# 1999                 NaN
#
# [2000 rows x 37 columns]

# %%
def results(endpointdf, records):
        client = Socrata("data.cityofnewyork.us", None)
        data = client.get(endpointdf, limit=records)
        name = pd.DataFrame.from_records(data)
        return name 

results("jt7v-77mi", 10)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#   summons_number plate_id registration_state plate_type  \
# 0     1361929741  FCJ5493                 NY        PAS
# 1     1366962000  63540MC                 NY        COM
# 2     1342296187  GCY4187                 NY        SRF
# 3     1342296199  95V6675                 TX        PAS
# 4     1342296217  FYM5117                 NY        SRF
# 5     1356906515  GFM1421                 NY        PAS
# 6     1337077380  18972BB                 NY        999
# 7     1364523796  WNJ4730                 VA        PAS
# 8     1359914924  68091JZ                 NY        COM
# 9     1355498326  EWV4127                 NY        PAS
#
#                 issue_date violation_code vehicle_body_type vehicle_make  \
# 0  1970-12-18T00:00:00.000             20              SUBN          GMC
# 1  1971-02-02T00:00:00.000             46              DELV        FRUEH
# 2  1971-09-18T00:00:00.000             21               VAN         FORD
# 3  1971-09-18T00:00:00.000             21               NaN          GMC
# 4  1971-09-18T00:00:00.000             21              SUBN        NISSA
# 5  1971-09-18T00:00:00.000             40               SDN        MAZDA
# 6  1971-10-10T00:00:00.000             14               BUS        INTER
# 7  1973-04-05T00:00:00.000             14               SDN        TOYOT
# 8  1973-07-22T00:00:00.000             46              DELV        TOYOT
# 9  1973-08-12T00:00:00.000             21              SUBN        ACURA
#
#   issuing_agency street_code1  ... law_section sub_division  \
# 0              S        35030  ...         408           E2
# 1              P        58830  ...         408           F1
# 2              S        11790  ...         408           D1
# 3              S        11790  ...         408           D1
# 4              S        28190  ...         408           D1
# 5              X        13610  ...         408            C
# 6              P         8440  ...         408            C
# 7              P        50830  ...         408            C
# 8              P        10610  ...         408           F4
# 9              X        42630  ...         408           D1
#
#   days_parking_in_effect from_hours_in_effect to_hours_in_effect  \
# 0                BBBBBBB                  ALL                ALL
# 1                BBBBBBB                  ALL                ALL
# 2                BBYBBBB                0930A              1100A
# 3                BBYBBBB                0930A              1100A
# 4                BBYBBBB                0930A              1100A
# 5                BBBBBBB                  ALL                ALL
# 6                BBBBBBB                0700A              0400P
# 7                BBBBBBB                0400P              0700P
# 8                BBBBBBB                  ALL                ALL
# 9                YYYYYYB                0800A              0830A
#
#   vehicle_color unregistered_vehicle vehicle_year meter_number feet_from_curb
# 0         BLACK                    0         2013            -              0
# 1           BRN                    0         2013            -              0
# 2          BLUE                    0         2002            -              0
# 3         SILVR                    0         2008            -              0
# 4         WHITE                    0         2012            -              0
# 5           BLK                    0         2010            -              7
# 6         YELLO                    0         2001            -              0
# 7           BLK                    0            0            -              0
# 8            WH                    0         2010            -              0
# 9          GREY                    0         2005            -              0
#
# [10 rows x 35 columns]

# %%
response = requests.get('https://data.cityofnewyork.us/resource/7mxj-7a6y.csv')
if response.ok:
    data = response.content

data
# Out:
# b'"summons_number","plate_id","registration_state","plate_type","issue_date","violation_code","vehicle_body_type","vehicle_make","issuing_agency","street_code1","street_code2","street_code3","vehicle_expiration_date","violation_location","violation_precinct","issuer_precinct","issuer_code","issuer_command","issuer_squad","violation_time","time_first_observed","violation_county","violation_in_front_of_or","house_number","street_name","intersecting_street","date_first_observed","law_section","sub_division","violation_legal_code","days_parking_in_effect","from_hours_in_effect","to_hours_in_effect","vehicle_color","unregistered_vehicle","vehicle_year","meter_number","feet_from_curb","violation_post_code","violation_description","no_standing_or_stopping","hydrant_violation","double_parking_violation"\n"1457617912","JEB5683","NY","PAS","2021-06-25T00:00:00.000","40","VAN","FORD","P","63430","69230","13490","20221004","88","88","88","967603","0088","0000","0130A","0125A","K","O","100","NORTH PORTLAND AVE",,"0","408","C4",,"BBBBBBB","ALL","ALL","GY","0","2007","-","3",,,,,\n"1457617924","JAN2986","NY","PAS","2021-06-25T00:00:00.000","20","SUBN","DODGE","P","13490","40404","40404","20221203","88","88","88","967603","0088","0000","0225A","0215A","K","F","398","AUBURN PLACE",,"20210625","408","E2",,"BBBBBBB","ALL","ALL","BLU","0","2007","-","0",,,,,\n"1457622427","FJH6630","TX","PAS","2021-06-17T00:00:00.000","98","SDN","AUDI","P","79430","47130","11750","0","88","88","88","969730","0088","0000","0809P",,"K","F","170","SOUTH PORTLAND AVE",,"0","408","E2",,"BBBBBBB","ALL","ALL","WHITE","0","0","-","0",,,,,\n"1457638629","RD1Y5N","MO","PAS","2021-06-16T00:00:00.000","98","SDN","TOYOT","P","53130","23230","23930","0","83","83","83","944434","0083","0000","0605P",,"K","F","22","JEFFERSON ST",,"0","408","C4",,"BBBBBBB","ALL","ALL","TAN","0","2001","-","0",,,,,\n"1457639580","T503814C","NY","OMT","2021-07-04T00:00:00.000","40","TAXI","HONDA","P","81030","23930","40030","20210831","83","83","83","962452","0083","0000","1058P",,"K","F","25","STANHOPE ST",,"0","408","F2",,"BBBBBBB","ALL","ALL","WHI","0","2020","-","0",,,,,\n"1457643042","JLN5490","NY","PAS","2021-06-28T00:00:00.000","98","SDN","HONDA","P","0","40404","40404","20211021","83","83","83","964362","0083","0000","1120A",,"K","F","234","MENEHAN ST",,"0","408","D",,"BBBBBBB","ALL","ALL","GRY","0","2015","-","0",,,,,\n"1457663909","UMB4505","VA","PAS","2021-07-02T00:00:00.000","98","SDN","SUBAR","P","42130","58330","59640","0","94","94","94","964223","0094","0000","0905A",,"K","F","197","FREEMAN ST",,"0","408","F2",,"BBBBBBB","ALL","ALL","GREEN","0","0","-","0",,,,,\n"1457670471","JPS7544","NY","PAS","2021-06-19T00:00:00.000","40","SDN","NISSA","P","85330","55730","73050","20220518","79","79","49","967937","0049","0000","0740P",,,"F","417","THROOP AVE",,"0","408","E2",,"BBBBBBB","ALL","ALL","RED","0","2015","-","0",,,,,\n"1457670537","UPS7544","NY","PAS","2021-06-19T00:00:00.000","70","SDN","NISSA","P","85330","55730","73050","20220518","79","79","79","967937","0079","0000","0740P",,,"F","417","THROOP AVE",,"0","408","E2",,"BBBBBBB","ALL","ALL","RED","0","2015","-","0",,,,,\n"1457677623","07027R5","TX","PAS","2021-07-03T00:00:00.000","74","SUBN","LEXUS","P","46820","65320","15920","20210524","41","41","41","953198","0041","0000","0600A","1140P",,"F","1035","LONGWOOD AVE",,"20210702","408","E2",,"BBBBBBB","ALL","ALL","WHT","0","2017","-","0",,,,,\n"1457677635","07027R5","TX","PAS","2021-07-03T00:00:00.000","40","SUBN","LEXUS","P","46820","65320","15920","20210524","41","41","41","953198","0041","0000","0600A","1140P","BX","F","1035","LONGWOOD AVE",,"20210702","408","J2",,"BBBBBBB","ALL","ALL","WHT","0","2017","-","0",,,,,\n"1457732816","T649424C","NY","PAS","2021-07-08T00:00:00.000","20","SDN","TOYOT","P","27180","52120","21820","20210531","46","46","46","965173","0046","0000","0850A","0850A","BX","F","120","E 184 ST",,"20210708","408","E2",,"BBBBBBB","ALL","ALL","WHITE","0","2001","-","0" ...

# %%
from xml.etree import ElementTree
response = requests.get('https://www.jewishvirtuallibrary.org/palestinian-rocket-and-mortar-attacks-against-israel')

if response.ok:
    root = ElementTree.fromstring(response.content)
    else:
        raise Exception('Could not parse')

# %%
response
# Out:
# <Response [403]>

# %%
records = [
    {
        field.tag: field.text
        for field in child
    }
    for child in root
]

records[:2]

# %%
ElementTree.fromstring(response.content)
# Out:
# Traceback (most recent call last):
#
#   File ~/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3548 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[11], line 1
#     ElementTree.fromstring(response.content)
#
#   File ~/.python/current/lib/python3.10/xml/etree/ElementTree.py:1342 in XML
#     parser.feed(text)
#
#   File <string>
# ParseError: mismatched tag: line 1, column 409
